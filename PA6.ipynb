# %%
class SciCalc():
    def __init__(self):
        self.num1=num1
        self.num2=num2
    def addition():
        print("Addition: ",num1+num2)
    def subtraction():
        print("Subtraction: ", num1-num2)
    def multiplication():
        print("Multiplication: ", num1*num2)
    def division():
        if num2==0:
            print("Division: infintiy")
        else:
            print("Division: ", num1/num2)
    def square_root():
        import math
        print("Square Root: ", math.sqrt(num1))
    def square():
        print("Squared: ", num1**2)
    def cube():
        print("Cubed: ", num1**3)
    def power():
        print(num1, "raised to the power of", num2, "is", num1**num2)
    def average():
        print("The average is: ", (num1+num2)/2)
    def area_circle():
        import math
        print("The area of your circle is: ", math.pi*(num1**2))
    def perimeter_circle():
        import math
        print("The perimeter of your circle is", 2*math.pi*num1)
    def area_rectangle():
        print("The area of your rectangel is:", num1*num2)
    def perimeter_rectangle():
        print("The perimerter of your rectangle is: ", (num1*2)+(num2*2))
    def remainder():
        print("The remainder of your divison is:", num1%num2)
    def even_or_odd():
        if num1%2==0:
            print("Your number is even")
        else:
            print("Your number is odd")
while True:
    print("Pick from one of the options: ")
    print("1.add")
    print("2.subtract")
    print("3.multiply")
    print("4.divide")
    print("5.square root")
    print("6.square")
    print("7.cube")
    print("8.power")
    print("9.average of 2 numbers")
    print("10.area of a circle")
    print("11.perimeter of a circle ")
    print("12.area of a rectangle")
    print("13.perimeter of a rectangle")
    print("14.remainder")
    print("15.even or odd")
    print("16.stop")
    choice=int(input("Enter your choice (1-16): "))
    if choice == 1:
        num1=float(input("Input your first number: "))
        num2=float(input("Input your second number: "))
        SciCalc.addition()
        print("-----------------------------------------------------")
    elif choice==2:
        num1=float(input("Input your first number: "))
        num2=float(input("Input your second number: "))
        SciCalc.subtraction()
        print("-----------------------------------------------------")
    elif choice==3: 
        num1=float(input("Input your first number: "))
        num2=float(input("Input your second number: "))
        SciCalc.multiplication()
        print("-----------------------------------------------------")
    elif choice==4:
        num1=float(input("Input your first number: "))
        num2=float(input("Input your second number: "))
        SciCalc.division()
        print("-----------------------------------------------------")
    elif choice==5: 
        num1=float(input("Input your first number: "))
        SciCalc.square_root()
        print("-----------------------------------------------------")
    elif choice==6:
        num1=float(input("Input your base number: "))
        SciCalc.square()
        print("-----------------------------------------------------")
    elif choice==7:
        num1=float(input("Input your base number: "))
        SciCalc.cube()
        print("-----------------------------------------------------")
    elif choice==8:
        num1=float(input("Input your base number: "))
        num2=float(input("Input your power: "))
        SciCalc.power()
        print("-----------------------------------------------------")
    elif choice==9:
        num1=float(input("Input your first number: "))
        num2=float(input("Input your second number: "))
        SciCalc.average()
        print("-----------------------------------------------------")
    elif choice==10:
        num1=float(input("Input your radius: "))
        SciCalc.area_circle()
        print("-----------------------------------------------------")
    elif choice==11:
        num1=float(input("Input your radius number: "))
        SciCalc.perimeter_circle()
        print('-----------------------------------------------------')
    elif choice==12:
        num1=float(input("Input your side length: "))
        num2=float(input("Input your side width: "))
        SciCalc.area_rectangle()
        print("-----------------------------------------------------")
    elif choice==13:
        num1=float(input("Input your side length: "))
        num2=float(input("Input your side width: "))
        SciCalc.perimeter_rectangle()
        print("-----------------------------------------------------")
    elif choice==14:
        num1=float(input("Input your first number: "))
        num2=float(input("Input your second number: "))
        SciCalc.remainder()
        print("-----------------------------------------------------")
    elif choice==15:
        num1=float(input("Input your  number: "))
        SciCalc.even_or_odd()
        print("-----------------------------------------------------")
    elif choice==16:
        break 
    else:
        print ("invalid choice, pick again")
# Out:
# Pick from one of the options:
# 1.add
# 2.subtract
# 3.multiply
# 4.divide
# 5.square root
# 6.square
# 7.cube
# 8.power
# 9.average of 2 numbers
# 10.area of a circle
# 11.perimeter of a circle
# 12.area of a rectangle
# 13.perimeter of a rectangle
# 14.remainder
# 15.even or odd
# 16.stop
# Enter your choice (1-16): 5
# Input your first number: 25
# Square Root:  5.0
# -----------------------------------------------------
# Pick from one of the options:
# 1.add
# 2.subtract
# 3.multiply
# 4.divide
# 5.square root
# 6.square
# 7.cube
# 8.power
# 9.average of 2 numbers
# 10.area of a circle
# 11.perimeter of a circle
# 12.area of a rectangle
# 13.perimeter of a rectangle
# 14.remainder
# 15.even or odd
# 16.stop
# Enter your choice (1-16): 16

# %% [markdown]
# # Carter Spalding

# %% [markdown]
# ## PA5

# %% [markdown]
# ### CS-150 Fall Semester

# %% [markdown]
# #### Version 1
